# %%
import pandas as pd
from sqlalchemy import *

db_path = 'postgresql://eqpytyddkgzpje:589827916509690e9baa1abd869d99bd85ac3c9902c361d04c1e560c2befd624@ec2-52-54-38-229.compute-1.amazonaws.com:5432/dap64di8scvd9n'
eng = create_engine(db_path)

# %%
pd.read_sql('''select * from "Confirmation";''',eng).head(10)

# %%
pd.read_sql('''select * from "Location";''',eng).head(10)
# Out:
#    id  annotation_id  azimuth  elevation  color
# 0   1              1      312         42      1
# 1   2              1      235        -29      2
# 2   3              1       51         41      3
# 3   4              1      129        -30      4
# 4   5              2      299          1      1
# 5   6              2       89          1      2
# 6   7              3       92         -2      2
# 7   8              3      304         34      3
# 8   9              3      232        -29      4
# 9  10              4      288          2      1

# %%
pd.read_sql('''select * from "Survey";''',eng).head(10)
# Out:
#    id                             survey_id
# 0   1  d93067d2-54ec-47cf-8285-1c667281603c
# 1   2  2b6dc55b-9e89-495b-9d8d-69766f42de66
# 2   3  2f33f6f6-b97b-41e4-9c33-398bed09478c
# 3   4  e1ead048-8569-4100-b174-448ea94d2fd8
# 4   5  b540031b-37fe-406c-962e-ddc7c520f303
# 5   6  f2d98405-3042-45cb-aaae-5f57a2d2426f
# 6   7  e30b7519-bfe5-48cd-892f-14123ad679a6
# 7   8  1dc16880-50f1-4890-a293-961cbda1c5c5
# 8   9  0104ff62-2d2e-4a1f-94f8-29f43563ca9a
# 9  10  0fd98a13-ebde-455d-a920-05269375a48e

# %%
pd.read_sql('''select * from "Annotation";''',eng).head(10)
# Out:
#    id                             survey_id  recording_id  source_count
# 0   1  d93067d2-54ec-47cf-8285-1c667281603c            22             4
# 1   2  2b6dc55b-9e89-495b-9d8d-69766f42de66            21             2
# 2   3  2f33f6f6-b97b-41e4-9c33-398bed09478c            11             4
# 3   4  e1ead048-8569-4100-b174-448ea94d2fd8            12             4
# 4   5  b540031b-37fe-406c-962e-ddc7c520f303            14             8
# 5   6  f2d98405-3042-45cb-aaae-5f57a2d2426f            27             6
# 6   7  e30b7519-bfe5-48cd-892f-14123ad679a6            23             8
# 7   8  1dc16880-50f1-4890-a293-961cbda1c5c5            27             6
# 8   9  0104ff62-2d2e-4a1f-94f8-29f43563ca9a            20             9
# 9  10  0fd98a13-ebde-455d-a920-05269375a48e            10             2

# %%
pd.read_sql('''select * from "Location";''',eng).head(10)
# Out:
#    id  annotation_id  azimuth  elevation  color
# 0   1              1      312         42      1
# 1   2              1      235        -29      2
# 2   3              1       51         41      3
# 3   4              1      129        -30      4
# 4   5              2      299          1      1
# 5   6              2       89          1      2
# 6   7              3       92         -2      2
# 7   8              3      304         34      3
# 8   9              3      232        -29      4
# 9  10              4      288          2      1

# %%
pd.read_sql('''select * from "Interaction";''',eng).head(10)
# Out:
#    id  annotation_id   action_type value               timestamp
# 0   1              1    play audio  None 2022-01-27 07:00:47.360
# 1   2              1  source count     4 2022-01-27 07:00:59.985
# 2   3              1       azimuth   312 2022-01-27 07:01:00.840
# 3   4              1     elevation    42 2022-01-27 07:01:01.580
# 4   5              1       azimuth   235 2022-01-27 07:01:02.246
# 5   6              1     elevation   -29 2022-01-27 07:01:02.928
# 6   7              1       azimuth    51 2022-01-27 07:01:03.778
# 7   8              1     elevation    41 2022-01-27 07:01:04.861
# 8   9              1       azimuth   129 2022-01-27 07:01:05.910
# 9  10              1     elevation   -30 2022-01-27 07:01:06.827

# %%
pd.read_sql('''select * from "Recording";''',eng).head(10)
# Out:
#    id               recording_name file_name  num_annotation  \
# 0   1  sources_3_recording_130.wav     0.wav               0
# 1   2   sources_9_recording_10.wav     1.wav               0
# 2   4  sources_1_recording_157.wav     3.wav               0
# 3   5  sources_5_recording_129.wav     4.wav               0
# 4   6   sources_6_recording_80.wav     5.wav               0
# 5   7   sources_6_recording_51.wav     6.wav               0
# 6   8   sources_7_recording_48.wav     7.wav               0
# 7   9  sources_8_recording_135.wav     8.wav               0
# 8  13  sources_2_recording_107.wav    12.wav               0
# 9  15  sources_5_recording_125.wav    14.wav               0
#
#    actual_num_source
# 0                  3
# 1                  9
# 2                  1
# 3                  5
# 4                  6
# 5                  6
# 6                  7
# 7                  8
# 8                  2
# 9                  5
