# %%
import pandas as pd
from sqlalchemy import *

db_path = 'postgresql://eqpytyddkgzpje:589827916509690e9baa1abd869d99bd85ac3c9902c361d04c1e560c2befd624@ec2-52-54-38-229.compute-1.amazonaws.com:5432/dap64di8scvd9n'
# db_path = 'postgresql://anniezheng@localhost/test'
eng = create_engine(db_path)

# %%
pd.read_sql('''select * from "Survey" order by id desc''',eng).head(10)
# Out:
#    id                             survey_id
# 0  33  91d72dc9-1ac8-44b9-83b8-dcc4f009a1fb
# 1  32  378f96d9-ace6-4b68-a225-a859e85c5c4e
# 2  31  e6cd5508-0b08-4687-860c-f626832e211d
# 3  30  f5d5df28-5fe6-4d6f-b432-be1ddd4b093e
# 4  29  55c6d8b8-f7d8-46ee-99e3-d012c90873f7
# 5  28  1f2a51a7-46b7-4981-acbc-ebfd0962b2ba
# 6  27  29df2c77-ae4d-4088-a2a7-a5efbe018de8
# 7  26  52ec20ce-6c3c-4c2c-baf1-e8961e420006
# 8  25  b80e66b3-e8e2-47eb-a7b3-9705aa74de81
# 9  24  f9cd54a8-26e1-4b99-9d04-25ffdef3bf4d

# %%
pd.read_sql('''select * from "Annotation";''',eng).head(10)
# Out:
#    id                             survey_id  recording_id  source_count  \
# 0   1  1b88c396-0fd2-4a66-9c5d-98ecf540ce4e            17             1
# 1   2  4d9f0f18-830e-495e-bc3f-480add601bcd            15             6
# 2   3  934523d9-f1f7-48d3-993e-26e24dd858de             8             4
# 3   4  9add8fac-1ef2-48cc-8508-919d7a41ade2            25             9
# 4   5  c43ccd90-8cb1-4739-a26c-5fd18c502f3c            25             8
# 5   6  b01f3be9-ee72-410a-ae10-e366e5df3fe4            16             2
# 6   7  ce3ffb82-153e-47ac-acdc-438224604f43            26             4
# 7   8  c26e8f19-6ff3-46c9-8dd4-3c74149ae09b            23             4
# 8   9  5018c867-e72d-4acb-8b92-159b577dbef0            10             3
# 9  10  cd2c6aa1-1263-4252-a605-a5d2f660a158            28             3
#
#                                            user_note  practice_round
# 0                            people on the left side           False
# 1  Horn to the right, then cat then something mus...           False
# 2   music left\ncat back\ncar horn right\nflute back           False
# 3  Keys right\ndryer\npeople talking\ngato\nwind\...           False
# 4                                                              False
# 5                               music left, dog back           False
# 6  rooster right, \ndot left, \nalarm back, \npeo...           False
# 7        rooster left, music right keys, car horn(?)           False
# 8                                                              False
# 9                                   cat human engine           False

# %%
pd.read_sql('''select * from "Location";''',eng)
# Out:
#       id annotation_id  azimuth  elevation  practice_round
# 0      1             1      275          2           False
# 1      2             2       90          0           False
# 2      3             2       70          0           False
# 3      4             2       45          0           False
# 4      5             2       30          0           False
# ..   ...           ...      ...        ...             ...
# 146  147            44      182          1           False
# 147  148            44      198          4           False
# 148  149            44      233          3           False
# 149  150            44       91         -2           False
# 150  151            44       90         -1           False
#
# [151 rows x 5 columns]

# %%
pd.read_sql('''select * from "Confirmation";''',eng)
# Out:
#     id  recording_id  source_id  location_id
# 0    1            17         47          1.0
# 1    2             8          4          8.0
# 2    3             8         36          9.0
# 3    4             8         71         10.0
# 4    5             8         31         11.0
# ..  ..           ...        ...          ...
# 69  70             5          2        126.0
# 70  71             5          4        127.0
# 71  72             5          9        128.0
# 72  73             5         25          NaN
# 73  74             5         56          NaN
#
# [74 rows x 4 columns]

# %%
pd.read_sql('''select * from "Recording" order by id;''',eng)
# Out:
#     id                recording_name file_name  num_annotation  \
# 0    1   sources_3_recording_130.wav     0.wav              10
# 1    2    sources_9_recording_10.wav     1.wav               1
# 2    3   sources_3_recording_160.wav     2.wav               6
# 3    4   sources_1_recording_157.wav     3.wav               1
# 4    5   sources_5_recording_129.wav     4.wav               1
# 5    6    sources_6_recording_80.wav     5.wav               1
# 6    7    sources_6_recording_51.wav     6.wav               0
# 7    8    sources_7_recording_48.wav     7.wav               1
# 8    9   sources_8_recording_135.wav     8.wav               1
# 9   10    sources_2_recording_52.wav     9.wav               3
# 10  11   sources_4_recording_139.wav    10.wav               0
# 11  12    sources_5_recording_46.wav    11.wav               1
# 12  13   sources_2_recording_107.wav    12.wav               0
# 13  14   sources_9_recording_194.wav    13.wav               0
# 14  15   sources_5_recording_125.wav    14.wav               3
# 15  16    sources_2_recording_64.wav    15.wav               1
# 16  17   sources_1_recording_190.wav    16.wav               1
# 17  18  sources_10_recording_151.wav    17.wav               2
# 18  19    sources_7_recording_68.wav    18.wav               0
# 19  20   sources_10_recording_54.wav    19.wav               0
# 20  21    sources_8_recording_51.wav    20.wav               1
# 21  22  sources_10_recording_160.wav    21.wav               0
# 22  23   sources_7_recording_145.wav    22.wav               1
# 23  24     sources_3_recording_8.wav    23.wav               2
# 24  25   sources_8_recording_162.wav    24.wav               2
# 25  26   sources_4_recording_102.wav    25.wav               1
# 26  27   sources_6_recording_190.wav    26.wav               0
# 27  28    sources_4_recording_67.wav    27.wav               1
# 28  29   sources_9_recording_164.wav    28.wav               0
# 29  30    sources_1_recording_46.wav    29.wav               0
# 30  31    sources_3_recording_57.wav    30.wav               0
# 31  32   sources_3_recording_150.wav    31.wav               0
#
#     actual_num_source
# 0                   3
# 1                   9
# 2                   3
# 3                   1
# 4                   5
# 5                   6
# 6                   6
# 7                   7
# 8                   8
# 9                   2
# 10                  4
# 11                  5
# 12                  2
# 13                  9
# 14                  5
# 15                  2
# 16                  1
# 17                 10
# 18                  7
# 19                 10
# 20                  8
# 21                 10
# 22                  7
# 23                  3
# 24                  8
# 25                  4
# 26                  6
# 27                  4
# 28                  9
# 29                  1
# 30                  3
# 31                  3

# %%
pd.read_sql('''select * from "Recording" where actual_num_source = 3;''',eng)
# Out:
#    id               recording_name file_name  num_annotation  \
# 0  24    sources_3_recording_8.wav    23.wav               2
# 1   3  sources_3_recording_160.wav     2.wav               6
# 2   1  sources_3_recording_130.wav     0.wav              10
# 3  31   sources_3_recording_57.wav    30.wav               0
# 4  32  sources_3_recording_150.wav    31.wav               0
#
#    actual_num_source
# 0                  3
# 1                  3
# 2                  3
# 3                  3
# 4                  3

# %%
pd.read_sql('''select * from "Source";''',eng)
# Out:
#     id                  file_name                  coarse_class  \
# 0    1        airplane_2_norm.wav  large transportation methods
# 1    2         boiling_1_norm.wav               domestic sounds
# 2    3       car_alarm_1_norm.wav                        alarms
# 3    4             cat_1_norm.wav                       animals
# 4    5             cat_2_norm.wav                       animals
# ..  ..                        ...                           ...
# 78  79            wind_3_norm.wav                natural sounds
# 79  80            wind_4_norm.wav                natural sounds
# 80  81  person_talking_4_norm.wav                   human voice
# 81  82     dog_barking_3_norm.wav                       animals
# 82  83          violin_4_norm.wav                        musics
#
#      specific_class
# 0          Airplane
# 1   Boiling Liquids
# 2         Car Alarm
# 3       Cat Meowing
# 4       Cat Meowing
# ..              ...
# 78             Wind
# 79             Wind
# 80   Person Talking
# 81      Dog Barking
# 82           Violin
#
# [83 rows x 4 columns]

# %%
pd.read_sql('''select * from "Recording_Joint_Source";''',eng)
# Out:
#      recording_id  source_id  azimuth  elevation
# 0               1         68       85          0
# 1               1         22       40        -30
# 2               1          9      230         30
# 3               2         29      190          0
# 4               2          4      325         30
# ..            ...        ...      ...        ...
# 166            31         81       30          0
# 167            31         25       75          0
# 168            32         82      -30          0
# 169            32         72       30          0
# 170            32         83        0          0
#
# [171 rows x 4 columns]
