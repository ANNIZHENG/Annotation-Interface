# %%
import pandas as pd
import os
from sqlalchemy import *

db_path = 'postgresql://eqpytyddkgzpje:589827916509690e9baa1abd869d99bd85ac3c9902c361d04c1e560c2befd624@ec2-52-54-38-229.compute-1.amazonaws.com:5432/dap64di8scvd9n'
eng = create_engine(db_path)

# %%
pd.read_sql('''select * from "Recording_Joint_Source";''',eng).head()
# Out:
#    recording_id  source_id  azimuth  elevation
# 0             1         68       85          0
# 1             1         22       40        -30
# 2             1          9      230         30
# 3             2         29      190          0
# 4             2          4      325         30

# %%
pd.read_sql('''select * from "Source";''',eng)
# Out:
#     id             file_name                  coarse_class   specific_class
# 0    1   airplane_2_norm.wav  large transportation methods         Airplane
# 1    2    boiling_1_norm.wav               domestic sounds  Boiling Liquids
# 2    3  car_alarm_1_norm.wav                        alarms        Car Alarm
# 3    4        cat_1_norm.wav                       animals      Cat Meowing
# 4    5        cat_2_norm.wav                       animals      Cat Meowing
# ..  ..                   ...                           ...              ...
# 75  76    trumpet_4_norm.wav                         music          Trumpet
# 76  77     violin_2_norm.wav                         music          Trumpet
# 77  78     violin_3_norm.wav                         music          Trumpet
# 78  79       wind_3_norm.wav                natural sounds             Wind
# 79  80       wind_4_norm.wav                natural sounds             Wind
#
# [80 rows x 4 columns]

# %%
pd.read_sql('''select * from "Survey";''',eng).head()
# Out:
#    id                             survey_id
# 0   1  d93067d2-54ec-47cf-8285-1c667281603c
# 1   2  2b6dc55b-9e89-495b-9d8d-69766f42de66
# 2   3  2f33f6f6-b97b-41e4-9c33-398bed09478c

# %%
pd.read_sql('''select * from "Annotation";''',eng).head()
# Out:
#    id                             survey_id  recording_id  source_count
# 0   1  d93067d2-54ec-47cf-8285-1c667281603c            22             4
# 1   2  2b6dc55b-9e89-495b-9d8d-69766f42de66            21             2
# 2   3  2f33f6f6-b97b-41e4-9c33-398bed09478c            11             4

# %%
pd.read_sql('''select * from "Location";''',eng)
# Out:
#    id  annotation_id  azimuth  elevation  color
# 0   1              1      312         42      1
# 1   2              1      235        -29      2
# 2   3              1       51         41      3
# 3   4              1      129        -30      4
# 4   5              2      299          1      1

# %%
pd.read_sql('''select * from "Interaction";''',eng)
# Out:
#     id  annotation_id   action_type value               timestamp
# 0    1              1    play audio  None 2022-01-27 07:00:47.360
# 1    2              1  source count     4 2022-01-27 07:00:59.985
# 2    3              1       azimuth   312 2022-01-27 07:01:00.840
# 3    4              1     elevation    42 2022-01-27 07:01:01.580
# 4    5              1       azimuth   235 2022-01-27 07:01:02.246
# 5    6              1     elevation   -29 2022-01-27 07:01:02.928
# 6    7              1       azimuth    51 2022-01-27 07:01:03.778
# 7    8              1     elevation    41 2022-01-27 07:01:04.861
# 8    9              1       azimuth   129 2022-01-27 07:01:05.910
# 9   10              1     elevation   -30 2022-01-27 07:01:06.827
# 10  11              1        submit  None 2022-01-27 07:01:08.480
# 11  12              2    play audio  None 2022-01-27 07:02:06.193
# 12  13              2  source count     2 2022-01-27 07:02:18.118
# ...

# %%
pd.read_sql('''select * from "Recording" order by num_annotation desc;''',eng)
# Out:
#     id                recording_name file_name  num_annotation  \
# 0   22  sources_10_recording_160.wav    21.wav               1
# 1   21    sources_8_recording_51.wav    20.wav               1
# 2   11   sources_4_recording_139.wav    10.wav               1
# 3    4   sources_1_recording_157.wav     3.wav               0
# 4    5   sources_5_recording_129.wav     4.wav               0
# 5    6    sources_6_recording_80.wav     5.wav               0
# 6    7    sources_6_recording_51.wav     6.wav               0
# 7    8    sources_7_recording_48.wav     7.wav               0
# 8    9   sources_8_recording_135.wav     8.wav               0
# 9   10    sources_2_recording_52.wav     9.wav               0
# 10  12    sources_5_recording_46.wav    11.wav               0
# 11  13   sources_2_recording_107.wav    12.wav               0
# 12  14   sources_9_recording_194.wav    13.wav               0
# 13  15   sources_5_recording_125.wav    14.wav               0
# ...
